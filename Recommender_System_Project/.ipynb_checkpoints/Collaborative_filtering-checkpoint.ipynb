# %%
######importing libraries for data manipulation#######
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import gzip
import math
from PIL import Image
import requests
from io import BytesIO
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import fbeta_score,precision_score,f1_score,recall_score,accuracy_score
from sklearn.linear_model import Perceptron
#from spark_sklearn import GridSearchCV
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import StratifiedKFold
from scipy import interp
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.linear_model import Ridge
from sklearn.linear_model import LogisticRegression
#import mord
from time import time
import matplotlib.patches as mpatches
import warnings
warnings.filterwarnings('ignore')
import scipy.stats as st
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV
import turicreate

# %%
###############Function definitions###########

#########Function definitions for separating related feature########
def change_vals_new_col(s,value,new_cols):
    
    if(value.get(s) != None):
        if((type(value[s]) == float) and np.isnan(value[s])):
            new_cols[s] = np.nan
        else:
            new_cols.get(s).append(value[s])
    else:
        new_cols.get(s).append(np.nan)
    

def generate_new_cols(related):
    
    new_cols = {'also_bought':[], 'also_viewed':[],'bought_together':[],'buy_after_viewing':[]}
    
    for key,value in related.items():
        if((type(value) == float) and np.isnan(value)):
            
            new_cols['also_bought'].append(np.nan)
            new_cols['also_viewed'].append(np.nan)
            new_cols['bought_together'].append(np.nan)
            new_cols['buy_after_viewing'].append(np.nan)
        else:
            change_vals_new_col('also_bought',value,new_cols)
            change_vals_new_col('also_viewed',value,new_cols)
            change_vals_new_col('bought_together',value,new_cols)
            change_vals_new_col('buy_after_viewing',value,new_cols)
            
        
    return new_cols
#####Function definitions for separating related feature ends####

def plot_related_prods(related,which,final_metadata):
    
    if(related == None):
        print('People who'+str(related)+'this product did not buy any other product:')
        return
    else:
        #print(np.array(related) in final_metadata.index)
        tot = 0
        for idx in related:
            if(idx in final_metadata.index):
                tot += 1
        print(tot)
        tot = round(tot/2)
        print('final',tot)
        f, axes = plt.subplots(tot,tot,figsize=(4,4),dpi=300)
        f.suptitle('People also '+str(which))
        for i in range(0,tot):
            for j in range(0,tot):
                curr_asin = related[i+j]
                if((curr_asin in final_metadata.index) == True):
                    curr_url = final_metadata.loc[curr_asin]['imUrl']
                    curr_title = final_metadata.loc[curr_asin]['title']
                    curr_title = curr_title[0:30]
                    response = requests.get(curr_url)
                    img = Image.open(BytesIO(response.content))
                    axes[i,j].imshow(img)
                    axes[i,j].get_xaxis().set_ticks([])
                    axes[i,j].get_yaxis().set_ticks([])
                    plt.axis('off')
                    axes[i,j].set_title(curr_title,size=3)
        plt.show()            

def Show_related_products(meta_data_row,final_metadata):
    
    #print(meta_data_row)
    curr_url = meta_data_row['imUrl']
    #curr_prod_id = meta_data_row['asin']
    title = meta_data_row['title']
    
    print('The current product is:',title)
    response = requests.get(curr_url)
    img = Image.open(BytesIO(response.content))
    plt.imshow(img)
    plt.show()
    
    ####People who bought this product also bought####
    also_bought = meta_data_row['also_bought']
    if((type(also_bought) == float) and np.isnan(also_bought)):
        also_bought = None
    else:
        if(len(also_bought) > 9):
            also_bought = also_bought[0:9]
    plot_related_prods(also_bought,'bought',final_metadata)
    
    ####People who bought this product also viewed####
    also_viewed = meta_data_row['also_viewed']
    if((type(also_viewed) == float) and np.isnan(also_viewed)):
        also_viewed = None
    else:
        if(len(also_viewed) > 9):
            also_viewed = also_viewed[0:9]
    plot_related_prods(also_viewed,'viewed',final_metadata)

def Collaborative_filtering(data,rec_data,recommend,s1=None,recc = 'collaborative'):
    
    train_data = turicreate.SFrame(rec_data)
    if(recc == 'collaborative'):
        item_sim_model = turicreate.item_similarity_recommender.create(train_data, user_id='reviewerID', item_id='asin', target='overall_binary', similarity_type='cosine')
    else:
        item_sim_model = turicreate.popularity_recommender.create(train_data, user_id='reviewerID', item_id='asin', target='overall_binary')
    
    rev_id = list(data.sample(3,random_state=333)['reviewerID'])
    item_sim_recomm = item_sim_model.recommend(users=rev_id,k=recommend)
    item_sim_recomm.print_rows(num_rows=25)
    
    
    if(s1 == None):
        path_list = ['user_1_photos/','user_2_photos/','user_3_photos/','user_4_photos/','user_5_photos/']
    else:
        path_list = ['user_11_photos/','user_22_photos/','user_33_photos/','user_44_photos/','user_55_photos/']
    
    for j in range(len(rev_id)):
        rev_data = data[data['reviewerID'] == rev_id[j]]
        l2 = list(rev_data['asin'])
        for i in range(len(l2)):
            title = final_metadata.loc[l2[i],'title']+' rating: '+str(rev_data.iloc[i,5])
            curr_url = final_metadata.loc[l2[i],'imUrl']
            response = requests.get(curr_url)
            img = Image.open(BytesIO(response.content))
            plt.title(title)
            plt.imshow(img)
            s = title.split('/')
            final_title = ''
            for i in range(len(s)):
                final_title = final_title + ' '+s[i]
                
            heading = final_title+' purchased by '+rev_id[j]+'.png'
            final_path = path_list[j]+heading
            print(final_path)
            plt.savefig(final_path,dpi=300)
            plt.show()
            
    #for j in range(len(rev_id)):
        l = list(item_sim_recomm[item_sim_recomm['reviewerID'] == rev_id[j]]['asin'])
        for i in range(len(l)):
            all_ratings = data[data['asin'] == l[i]]['overall']
            mean_rating = np.mean(all_ratings)
            title = final_metadata.loc[l[i],'title']+'| mean rating: '+str(np.round(mean_rating,decimals=2))+'| rank:'+str(i+1)
            curr_url = final_metadata.loc[l[i],'imUrl']
            response = requests.get(curr_url)
            img = Image.open(BytesIO(response.content))
            plt.title(title)
            plt.imshow(img)
            s = title.split('/')
            final_title = ''
            for i in range(len(s)):
                final_title = final_title + ' '+s[i]
                
            heading = final_title +' recommended to'+rev_id[j]+'.png'
            final_path = path_list[j]+heading
            plt.savefig(final_path,dpi=300)
            plt.show()

# %% [markdown]
# # Read Data

# %%
#####Reading Data##ata#####
#####This is a smaller data for initial data exploration and model testing#####
######The data is about Heal and Personal care Products on Amazon##########

def parse(path):
    g = open(path, 'rb')
    for l in g:
        yield eval(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

data_path = '/Users/ruchinpatel/Desktop/USC_EVERYTHING/SPRINGBOARD/CAPSTONE/Health_and_Personal_Care_5.json'
metadata_path = '/Users/ruchinpatel/Desktop/USC_EVERYTHING/SPRINGBOARD/CAPSTONE/meta_Health_and_Personal_Care.json'

data = getDF(data_path)
metadata = getDF(metadata_path)

# %%
########## Generating seperate columns for related feature######
related = metadata['related'].to_dict()
newly_created_columns = pd.DataFrame(generate_new_cols(related))

# %%
#########Final Metadata dataframe###########
final_metadata = pd.concat([metadata,newly_created_columns],axis = 1)
final_metadata = final_metadata.drop('related',axis=1)
final_metadata = final_metadata.set_index('asin')

######converting the dates to date time format#####
data['unixReviewTime'] = pd.to_datetime(data['unixReviewTime'],unit='s')
data['reviewTime'] = pd.to_datetime(data['reviewTime'])
replace = {1:0,2:0,3:0,4:1,5:1}
data['overall_binary'] = data[['overall']].replace(to_replace=replace,value=None)

# %%
data.head(10)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 346355 entries, 0 to 346354
# Data columns (total 10 columns):
# reviewerID        346355 non-null object
# asin              346355 non-null object
# reviewerName      343304 non-null object
# helpful           346355 non-null object
# reviewText        346355 non-null object
# overall           346355 non-null float64
# summary           346355 non-null object
# unixReviewTime    346355 non-null datetime64[ns]
# reviewTime        346355 non-null datetime64[ns]
# overall_binary    346355 non-null float64
# dtypes: datetime64[ns](2), float64(2), object(6)
# memory usage: 39.1+ MB

# %%
name = data[data['reviewerID'] == 'ALC5GH8CAMAI7']['reviewerName']
name
# Out:
# 0         AnnN
# 67549     AnnN
# 73107     AnnN
# 101342    AnnN
# 101404    AnnN
# 105435    AnnN
# 162430    AnnN
# Name: reviewerName, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 346355 entries, 0 to 346354
# Data columns (total 10 columns):
# reviewerID        346355 non-null object
# asin              346355 non-null object
# reviewerName      343304 non-null object
# helpful           346355 non-null object
# reviewText        346355 non-null object
# overall           346355 non-null float64
# summary           346355 non-null object
# unixReviewTime    346355 non-null datetime64[ns]
# reviewTime        346355 non-null datetime64[ns]
# overall_binary    346355 non-null float64
# dtypes: datetime64[ns](2), float64(2), object(6)
# memory usage: 39.1+ MB

# %%
final_metadata.head(10)
# Out:
#                                                   description  \
# asin
# 0077614992            This is an example product description.
# 0615208479  By now we all know the benefits of exercise fo...
# 0615269990  What's wrong with your patient?Do all the symp...
# 0615315860                                                NaN
# 0615406394            This is an example product description.
# 0615836828                                                NaN
# 0641710577  Foster Grant introduces a whole new dimension ...
# 0641864507  * Super bright LED light\n    * 2 CR2016 repla...
# 0681504498  Affordably priced. Hardcover or paper back, th...
# 0705394638  Beautiful memory book for you new baby boy to ...
#
#                                                         title  \
# asin
# 0077614992            Principles of Mgmt + Oper-CSUF Custom C
# 0615208479                   Brain Fitness Exercises Software
# 0615269990                                      Occam's Razor
# 0615315860           101 BlenderBottle Recipes Quick and Easy
# 0615406394  Aphrodite Reborn - Women's Stories of Hope, Co...
# 0615836828                Breast Cancer: My Spiritual Journey
# 0641710577  Foster Grant Women's Reading Glasses Romance W...
# 0641864507                               LED Travel Magnifier
# 0681504498                     Itty Bitty Paperback Booklight
# 0705394638  C.r. Gibson Baby Boy Zoom-Zoom Loose-leaf Memo...
#
#                                                         imUrl  \
# asin
# 0077614992  http://ecx.images-amazon.com/images/I/51G%2BRq...
# 0615208479  http://ecx.images-amazon.com/images/I/41kbZB04...
# 0615269990  http://ecx.images-amazon.com/images/I/51fH-ABe...
# 0615315860  http://ecx.images-amazon.com/images/I/21zOQu2Q...
# 0615406394  http://ecx.images-amazon.com/images/I/51rJLgsi...
# 0615836828  http://ecx.images-amazon.com/images/I/41UrGEwA...
# 0641710577  http://ecx.images-amazon.com/images/I/414Fx6sG...
# 0641864507  http://ecx.images-amazon.com/images/I/41ZlfiUd...
# 0681504498  http://ecx.images-amazon.com/images/I/31pQu4fW...
# 0705394638  http://ecx.images-amazon.com/images/I/51hf80nu...
#
#                                       salesRank  \
# asin
# 0077614992   {'Health & Personal Care': 168429}
# 0615208479  {'Health & Personal Care': 1346973}
# 0615269990             {'Toys & Games': 110575}
# 0615315860   {'Health & Personal Care': 254068}
# 0615406394   {'Health & Personal Care': 377936}
# 0615836828   {'Health & Personal Care': 603899}
# 0641710577  {'Health & Personal Care': 1039561}
# 0641864507                                  NaN
# 0681504498                                  NaN
# 0705394638    {'Health & Personal Care': 72478}
#
#                                                    categories  price  \
# asin
# 0077614992                         [[Health & Personal Care]]    NaN
# 0615208479          [[Health & Personal Care, Personal Care]]    NaN
# 0615269990  [[Health & Personal Care, Personal Care, Shavi...  34.99
# 0615315860                         [[Health & Personal Care]]    NaN
# 0615406394                         [[Health & Personal Care]]    NaN
# 0615836828                         [[Health & Personal Care]]    NaN
# 0641710577  [[Health & Personal Care, Personal Care, Eye C...    NaN
# 0641864507  [[Health & Personal Care, Medical Supplies & E...    NaN
# 0681504498  [[Health & Personal Care, Medical Supplies & E...  21.97
# 0705394638  [[Health & Personal Care, Stationery & Party S...    NaN
#
#                  brand                                        also_bought  \
# asin
# 0077614992         NaN  [0471730726, 0132834871, 0471391905, B00000JZK...
# 0615208479         NaN                                                NaN
# 0615269990         NaN  [1935660152, 0071743979, 0071831428, 032308787...
# 0615315860         NaN  [B006VT9RBM, B0010JLMO8, B001CXC69C, B0064QSHX...
# 0615406394         NaN                           [0966035232, 1421407205]
# 0615836828         NaN                                                NaN
# 0641710577         NaN                                                NaN
# 0641864507  UltraOptix                                                NaN
# 0681504498   Maxi-Aids                                                NaN
# 0705394638         NaN                                                NaN
#
#                                                   also_viewed bought_together  \
# asin
# 0077614992   [0073525057, 1133227295, 0324628676, 0073523224]             NaN
# 0615208479                                                NaN             NaN
# 0615269990  [1594741476, B0069628EU, B009RTGX2Y, B000IQHSL...             NaN
# 0615315860                                       [B0018G4ZEW]             NaN
# 0615406394                                                NaN             NaN
# 0615836828                                                NaN             NaN
# 0641710577                                                NaN             NaN
# 0641864507  [B002E3KJBG, 1935009656, B00524H98U, B00H8R6G9...             NaN
# 0681504498                           [1933622717, B00005R8TK]             NaN
# 0705394638  [B00AYZFKME, B001AL7GOQ, B007BG6BKE, B00AYZFFQ...             NaN
#
#                                            buy_after_viewing
# asin
# 0077614992                                               NaN
# 0615208479                                               NaN
# 0615269990                                               NaN
# 0615315860                                               NaN
# 0615406394                                               NaN
# 0615836828                                               NaN
# 0641710577                                               NaN
# 0641864507                                               NaN
# 0681504498  [1933622717, B00005R8TN, B000PER1DA, B00005R8TL]
# 0705394638                                               NaN

# %%
final_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 263032 entries, 0077614992 to B00LYPUPZK
# Data columns (total 11 columns):
# description          237839 non-null object
# title                262362 non-null object
# imUrl                262767 non-null object
# salesRank            247665 non-null object
# categories           263032 non-null object
# price                196043 non-null float64
# brand                124304 non-null object
# also_bought          120684 non-null object
# also_viewed          193140 non-null object
# bought_together      118616 non-null object
# buy_after_viewing    5160 non-null object
# dtypes: float64(1), object(10)
# memory usage: 24.1+ MB

# %%
users = data.reviewerID.unique().shape[0]
items = metadata.asin.unique().shape[0]

# %%
print(users)
print(items)
# Out:
# 38609
# 263032

# %%
for line in data.head(10).itertuples():
    print(line[1])
# Out:
# ALC5GH8CAMAI7
# AHKSURW85PJUE
# A38RMU1Y5TDP9
# A1XZUG7DFXXOS4
# A1MS3M7M7AM13X
# AXO4PQU0XG3TG
# A28X0LT2100RL1
# A1VUSWRVN8SJA8
# A1JQDCX4LDKBZ3
# A3RNRXOM5J2C93

# %%
r_index = data.reviewerID.unique()
c_index = data.asin.unique()

# %%
d = pd.DataFrame(0, index=r_index, columns=c_index)

# %%
for line in data.itertuples():
    d.ix[line[1]].loc[line[2]] = int(line[6])

# %%
np.unique(d)
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
d.head(10)
# Out:
#                 159985130X  1933622865  1935009656  3812028492  7884890364  \
# ALC5GH8CAMAI7            5           0           0           0           0
# AHKSURW85PJUE            4           0           0           0           0
# A38RMU1Y5TDP9            4           0           0           0           0
# A1XZUG7DFXXOS4           4           0           0           0           0
# A1MS3M7M7AM13X           5           0           0           0           0
# AXO4PQU0XG3TG            5           0           0           0           0
# A28X0LT2100RL1           4           0           0           0           0
# A1VUSWRVN8SJA8           5           0           0           0           0
# A1JQDCX4LDKBZ3           3           0           0           0           0
# A3RNRXOM5J2C93           4           0           0           0           0
#
#                 B00000J47L  B00000J9DU  B00000JHQ2  B00000JHQ6  B00000JHQC  \
# ALC5GH8CAMAI7            0           0           0           0           0
# AHKSURW85PJUE            0           0           0           0           0
# A38RMU1Y5TDP9            0           0           0           0           0
# A1XZUG7DFXXOS4           0           0           0           0           0
# A1MS3M7M7AM13X           0           0           0           0           0
# AXO4PQU0XG3TG            0           0           0           0           0
# A28X0LT2100RL1           0           0           0           0           0
# A1VUSWRVN8SJA8           0           0           0           0           0
# A1JQDCX4LDKBZ3           0           0           0           0           0
# A3RNRXOM5J2C93           0           0           0           0           0
#
#                    ...      B00L5L7ZPQ  B00L5LSO7E  B00L6FWTJ8  B00L9BRHGY  \
# ALC5GH8CAMAI7      ...               0           0           0           0
# AHKSURW85PJUE      ...               0           0           0           0
# A38RMU1Y5TDP9      ...               0           0           0           0
# A1XZUG7DFXXOS4     ...               0           0           0           0
# A1MS3M7M7AM13X     ...               0           0           0           0
# AXO4PQU0XG3TG      ...               0           0           0           0
# A28X0LT2100RL1     ...               0           0           0           0
# A1VUSWRVN8SJA8     ...               0           0           0           0
# A1JQDCX4LDKBZ3     ...               0           0           0           0
# A3RNRXOM5J2C93     ...               0           0           0           0
#
#                 B00LBE8SMG  B00LDUS8H8  B00LFB2ENY  B00LIASY0Y  B00LJBMCFA  \
# ALC5GH8CAMAI7            0           0           0           0           0
# AHKSURW85PJUE            0           0           0           0           0
# A38RMU1Y5TDP9            0           0           0           0           0
# A1XZUG7DFXXOS4           0           0           0           0           0
# A1MS3M7M7AM13X           0           0           0           0           0
# AXO4PQU0XG3TG            0           0           0           0           0
# A28X0LT2100RL1           0           0           0           0           0
# A1VUSWRVN8SJA8           0           0           0           0           0
# A1JQDCX4LDKBZ3           0           0           0           0           0
# A3RNRXOM5J2C93           0           0           0           0           0
#
#                 B00LJBMCKK
# ALC5GH8CAMAI7            0
# AHKSURW85PJUE            0
# A38RMU1Y5TDP9            0
# A1XZUG7DFXXOS4           0
# A1MS3M7M7AM13X           0
# AXO4PQU0XG3TG            0
# A28X0LT2100RL1           0
# A1VUSWRVN8SJA8           0
# A1JQDCX4LDKBZ3           0
# A3RNRXOM5J2C93           0
#
# [10 rows x 18534 columns]

# %%
##### Using Turi Create#######

# %%
#data_temp = data.head(1000)

# %%
rec_data = data[['reviewerID','asin','overall_binary']]

# %%
Collaborative_filtering(data,rec_data,3)
# Out:
# Preparing data set.
#     Data has 346355 observations with 38609 users and 18534 items.
#     Data prepared in: 0.630251s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 2.367ms                        | 2.5        |
# | 43.618ms                       | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.49s                               | 0                | 0               |
# | 8.13s                               | 100              | 18534           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 8.2796s
# +----------------+------------+----------------------+------+
# |   reviewerID   |    asin    |        score         | rank |
# +----------------+------------+----------------------+------+
# | A15VFMU0WO8ED2 | B001M5C29O | 0.025220311605013333 |  1   |
# | A15VFMU0WO8ED2 | B001U0OP46 | 0.021038284668555625 |  2   |
# | A15VFMU0WO8ED2 | B00005UKIB | 0.019230769230769232 |  3   |
# | AVSRLB4QXACSV  | B008RIFNZE | 0.03648096323013306  |  1   |
# | AVSRLB4QXACSV  | B001RADQGW | 0.03316164016723633  |  2   |
# | AVSRLB4QXACSV  | B009VJ2MX4 | 0.030290208756923676 |  3   |
# | AV2GFSSHXCODC  | B0044Z0A34 | 0.02777778108914693  |  1   |
# | AV2GFSSHXCODC  | B0002GMGBI | 0.02777778108914693  |  2   |
# | AV2GFSSHXCODC  | B008QMWKES | 0.02777778108914693  |  3   |
# +----------------+------------+----------------------+------+
# [9 rows x 4 columns]
#
# user_1_photos/ EDGE Sensitive Skin Advanced Mens SHAVE GEL Shaving NEW rating: 5.0 purchased by A15VFMU0WO8ED2.png
# user_1_photos/ Philips Sonicare HX6013 ProResults Brush Head Standard, 3-Pack rating: 5.0 purchased by A15VFMU0WO8ED2.png
# user_1_photos/ Maxell Watch Battery Button Cell SR626SW SR-626SW 377 Pack of 5 Batteries rating: 5.0 purchased by A15VFMU0WO8ED2.png
# user_1_photos/ Sony Lithium 3V Batteries Size CR2016 (Pack of 5) rating: 5.0 purchased by A15VFMU0WO8ED2.png
# user_1_photos/ Mr. Clean EXTRA POWER Magic Eraser - 10 Count rating: 5.0 purchased by A15VFMU0WO8ED2.png
# user_1_photos/ Philips Sonicare HX6972 30 Flexcare Plus Rechargeable Electric Toothbrush rating: 4.0 purchased by A15VFMU0WO8ED2.png
# user_1_photos/ Cascade ActionPacs Dishwasher Detergent Fresh Scent 85 Count rating: 5.0 purchased by A15VFMU0WO8ED2.png
# user_1_photos/ Waterpik Replacement Jet Tips - JT-100E - 2 Pack rating: 4.0 purchased by A15VFMU0WO8ED2.png
# user_1_photos/ Superfeet Yellow Premium Insoles rating: 5.0 purchased by A15VFMU0WO8ED2.png
# user_1_photos/ Mr. Clean Magic Eraser Variety Tub, 6 Count rating: 5.0 purchased by A15VFMU0WO8ED2.png
# user_1_photos/ Tide Pods Laundry Detergent Alpine Breeze Scent 18 Count rating: 5.0 purchased by A15VFMU0WO8ED2.png
# user_1_photos/ Lysol Disinfecting Wipes Value Pack, Lemon and Lime Blossom, 105 Count rating: 5.0 purchased by A15VFMU0WO8ED2.png
# user_1_photos/ Glad OdorShield Tall Kitchen Drawstring Trash Bags, Fresh Clean, 13 Gallon, 80 Count rating: 5.0 purchased by A15VFMU0WO8ED2.png
# user_2_photos/ Yerba Prima Bentonite, Detox Pint, 16 Ounce rating: 5.0 purchased by AVSRLB4QXACSV.png
# user_2_photos/ Renew Life - Ultimate Flora Critical Care 50 Billion - 30 - Veg Cap rating: 3.0 purchased by AVSRLB4QXACSV.png
# user_2_photos/ Wahl #12 clipper guide comb, 1&amp;1 2. rating: 3.0 purchased by AVSRLB4QXACSV.png
# user_2_photos/ Enzymatic Therapy - Pearls IC - 30 caps rating: 5.0 purchased by AVSRLB4QXACSV.png
# user_2_photos/ New Chapter Every Man's One Daily Multivitamin, 24 Tablets rating: 5.0 purchased by AVSRLB4QXACSV.png
# user_2_photos/ Organic India Whole Husk Psyllium, 12-Ounce rating: 4.0 purchased by AVSRLB4QXACSV.png
# user_2_photos/ Garden of Life Raw Organic Fiber, 803 Gram rating: 4.0 purchased by AVSRLB4QXACSV.png
# user_2_photos/ USP Labs Modern BCAA Plus Nutritional-Supplement, Watermelon, 18.89 Ounce rating: 5.0 purchased by AVSRLB4QXACSV.png
# user_3_photos/ Clif Bar Crunchy Peanut Butter (Box of 12) rating: 5.0 purchased by AV2GFSSHXCODC.png
# user_3_photos/ Handstands Cyber Gel Squeeze Ball - Colors may vary rating: 3.0 purchased by AV2GFSSHXCODC.png
# user_3_photos/ United Solutions Blue Plastic Utility Pail with Spout, 12-Quart rating: 2.0 purchased by AV2GFSSHXCODC.png
# user_3_photos/ #3 Stainless Steel Chinese Healthy Exercise Massage Metal Balls rating: 4.0 purchased by AV2GFSSHXCODC.png
# user_3_photos/ Maybelline New York Baby Lips Moisturizing Lip Balm, Pink Punch, 0.15 Ounce rating: 4.0 purchased by AV2GFSSHXCODC.png
# user_3_photos/ Clif Crunch Granola Bar, Peanut Butter, 5 Two-Bar Pouches 7.4 Ounce rating: 4.0 purchased by AV2GFSSHXCODC.png
